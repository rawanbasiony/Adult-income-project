# %%
# 1- read the dataframe fill
import numpy as np
import pandas as pd
df = pd.read_csv('C:/Users/m/Documents/adult.csv')
df [10:30]
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# 14   51                 ?  172175     Doctorate             16
# 15   46           Private   45363   Prof-school             15
# 16   45           Private  172822          11th              7
# 17   57           Private  317847       Masters             14
# 18   22           Private  119592    Assoc-acdm             12
# 19   34           Private  203034     Bachelors             13
# 20   37           Private  188774     Bachelors             13
# 21   29           Private   77009          11th              7
# 22   61           Private   29059       HS-grad              9
# 23   51           Private  153870  Some-college             10
# ...

# %%
# 2-show the data type of each column
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
# 3- get the shape of dataframe

df.shape
# Out:
# (32561, 15)

# %%
# 4- get info of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# 5- check the duplication

df.duplicated().any()
# Out:
# True

# %%
# 6- drop duplicated values

df = df.drop_duplicates()
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
# 7- get first 10 rows

df1 =df[0:10]
df1
# Out:
#    age    workclass  fnlwgt     education  education.num marital.status  \
# 0   90            ?   77053       HS-grad              9        Widowed
# 1   82      Private  132870       HS-grad              9        Widowed
# 2   66            ?  186061  Some-college             10        Widowed
# 3   54      Private  140359       7th-8th              4       Divorced
# 4   41      Private  264663  Some-college             10      Separated
# 5   34      Private  216864       HS-grad              9       Divorced
# 6   38      Private  150601          10th              6      Separated
# 7   74    State-gov   88638     Doctorate             16  Never-married
# 8   68  Federal-gov  422013       HS-grad              9       Divorced
# 9   41      Private   70037  Some-college             10  Never-married
#
#           occupation    relationship   race     sex  capital.gain  \
# 0                  ?   Not-in-family  White  Female             0
# ...

# %%
# anouther way to get first 10 rows

df.head(10)
# Out:
#    age    workclass  fnlwgt     education  education.num marital.status  \
# 0   90            ?   77053       HS-grad              9        Widowed
# 1   82      Private  132870       HS-grad              9        Widowed
# 2   66            ?  186061  Some-college             10        Widowed
# 3   54      Private  140359       7th-8th              4       Divorced
# 4   41      Private  264663  Some-college             10      Separated
# 5   34      Private  216864       HS-grad              9       Divorced
# 6   38      Private  150601          10th              6      Separated
# 7   74    State-gov   88638     Doctorate             16  Never-married
# 8   68  Federal-gov  422013       HS-grad              9       Divorced
# 9   41      Private   70037  Some-college             10  Never-married
#
#           occupation    relationship   race     sex  capital.gain  \
# 0                  ?   Not-in-family  White  Female             0
# ...

# %%
# 8- get last 10 rows

df.tail(10)
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 32551   43  Self-emp-not-inc   27242  Some-college             10
# 32552   32           Private   34066          10th              6
# 32553   43           Private   84661     Assoc-voc             11
# 32554   32           Private  116138       Masters             14
# 32555   53           Private  321865       Masters             14
# 32556   22           Private  310152  Some-college             10
# 32557   27           Private  257302    Assoc-acdm             12
# 32558   40           Private  154374       HS-grad              9
# 32559   58           Private  151910       HS-grad              9
# 32560   22           Private  201490       HS-grad              9
#
#            marital.status         occupation   relationship  \
# 32551  Married-civ-spouse       Craft-repair        Husband
# 32552  Married-civ-spouse  Handlers-cleaners        Husband
# ...

# %%
# 9- get column names in a list

columns= df.columns.to_list()
columns
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education.num',
#  'marital.status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital.gain',
#  'capital.loss',
#  'hours.per.week',
#  'native.country',
#  'income']

# %%
# 10- check null values

df.isnull().any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education.num     False
# marital.status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital.gain      False
# capital.loss      False
# hours.per.week    False
# native.country     True
# income            False
# dtype: bool

# %%
# 11- replace the value '?' with nan

df.replace("?", np.nan , inplace= True)
df[10:30]
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# 14   51               NaN  172175     Doctorate             16
# 15   46           Private   45363   Prof-school             15
# 16   45           Private  172822          11th              7
# 17   57           Private  317847       Masters             14
# 18   22           Private  119592    Assoc-acdm             12
# 19   34           Private  203034     Bachelors             13
# 20   37           Private  188774     Bachelors             13
# 21   29           Private   77009          11th              7
# 22   61           Private   29059       HS-grad              9
# 23   51           Private  153870  Some-college             10
# ...

# %%
# 12- to drop null values

#df= df.dropna()
#df

# %%
#13-fill null values with fillna() function

df['workclass'].fillna('private',inplace =True)
df['occupation'].fillna('other-service',inplace= True)
df['native.country'].fillna('United-States',inplace=True)
df

df[10:30]
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# 14   51           private  172175     Doctorate             16
# 15   46           Private   45363   Prof-school             15
# 16   45           Private  172822          11th              7
# 17   57           Private  317847       Masters             14
# 18   22           Private  119592    Assoc-acdm             12
# 19   34           Private  203034     Bachelors             13
# 20   37           Private  188774     Bachelors             13
# 21   29           Private   77009          11th              7
# 22   61           Private   29059       HS-grad              9
# 23   51           Private  153870  Some-college             10
# ...

# %%
df[10:30]
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# 14   51           private  172175     Doctorate             16
# 15   46           Private   45363   Prof-school             15
# 16   45           Private  172822          11th              7
# 17   57           Private  317847       Masters             14
# 18   22           Private  119592    Assoc-acdm             12
# 19   34           Private  203034     Bachelors             13
# 20   37           Private  188774     Bachelors             13
# 21   29           Private   77009          11th              7
# 22   61           Private   29059       HS-grad              9
# 23   51           Private  153870  Some-college             10
# ...

# %%
# 14- show a random sample 50%

df_sample50 =df.sample(frac=0.50)
df_sample50
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 13413   19           Private  278480  Some-college             10
# 3316    24           Private  117959       HS-grad              9
# 27028   31           Private  114691       HS-grad              9
# 24970   29           Private  100579     Assoc-voc             11
# 2786    38           Private  297449     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 22311   21           Private   43535  Some-college             10
# 15137   35           Private   54159       HS-grad              9
# 11186   40  Self-emp-not-inc  403550  Some-college             10
# 31919   30           Private  236543  Some-college             10
# 25122   29           Private   91547  Some-college             10
#
#            marital.status         occupation   relationship   race     sex  \
# 13413       Never-married    Exec-managerial  Not-in-family  White    Male
# ...

# %%
# 15- get overall statistics about the dataframe

df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32537.000000  3.253700e+04   32537.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.081815   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.571633   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# 16- histogram of age (the distribution) 

df['age'].plot(kind='hist', edgecolor='blue')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 17- make workclass column values numaric values(0,1)

one_hot_encoded_data1 = pd.get_dummies(df, columns =['workclass'] )
one_hot_encoded_data1
# Out:
#        age  fnlwgt     education  education.num      marital.status  \
# 0       90   77053       HS-grad              9             Widowed
# 1       82  132870       HS-grad              9             Widowed
# 2       66  186061  Some-college             10             Widowed
# 3       54  140359       7th-8th              4            Divorced
# 4       41  264663  Some-college             10           Separated
# ...    ...     ...           ...            ...                 ...
# 32556   22  310152  Some-college             10       Never-married
# 32557   27  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40  154374       HS-grad              9  Married-civ-spouse
# 32559   58  151910       HS-grad              9             Widowed
# 32560   22  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  ...  \
# 0          other-service  Not-in-family  White  Female             0  ...
# ...

# %%
# 18- histogram of workclass column (The Distribution)
one_hot_encoded_data1.plot(kind='hist', edgecolor='Red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 19- use .between() to find ages from 17 to 48  
age1=df['age'].between(17,48)
age1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 32556     True
# 32557     True
# 32558     True
# 32559    False
# 32560     True
# Name: age, Length: 32537, dtype: bool

# %%
# 20- Find Total Number of Persons Having Age Between 17 To 48 

totalnum=age1.sum()
totalnum
# Out:
# 24901

# %%
#df.insert(14, 'age_bt17_48', age1,True)
#df

# %%
#one_hot_encoded_data = pd.get_dummies(df, columns =['age_bt17_48'] )
#one_hot_encoded_data

# %%
# 21- the highest  fnlgwt

maxfnlgwt = df['fnlwgt'].max()
maxfnlgwt
# Out:
# 1484705

# %%
# 22- How Many Persons Having Bachelors and Masters Degree?

degree_count1=df['education'].value_counts()
degree_count1
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# 23- Get the correlation of data frame ?

df.corr()
# Out:
# C:\Users\m\AppData\Local\Temp\ipykernel_7744\3542764042.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076447       0.036224      0.077676      0.057745
# fnlwgt         -0.076447  1.000000      -0.043388      0.000429     -0.010260
# education.num   0.036224 -0.043388       1.000000      0.122664      0.079892
# capital.gain    0.077676  0.000429       0.122664      1.000000     -0.031639
# capital.loss    0.057745 -0.010260       0.079892     -0.031639      1.000000
# hours.per.week  0.068515 -0.018898       0.148422      0.078408      0.054229
#
#                 hours.per.week
# age                   0.068515
# fnlwgt               -0.018898
# education.num         0.148422
# ...

# %%
# 24- Convert workclass Column Datatype To Category Datatype?

df['workclass']= df['workclass'].astype('category')
df['workclass']
# Out:
# 0        private
# 1        Private
# 2        private
# 3        Private
# 4        Private
#           ...
# 32556    Private
# 32557    Private
# 32558    Private
# 32559    Private
# 32560    Private
# Name: workclass, Length: 32537, dtype: category
# Categories (9, object): ['Federal-gov', 'Local-gov', 'Never-worked', 'Private', ..., 'Self-emp-not-inc', 'State-gov', 'Without-pay', 'private']

# %%
# 25- heatmap of dataframe

import seaborn as sns
import matplotlib.pyplot as plt
corr = df.corr()

ax1 = sns.heatmap(corr, cbar=0, linewidths=2,vmax=1, vmin=0, square=True, cmap='Reds')
plt.show()
# Out:
# C:\Users\m\AppData\Local\Temp\ipykernel_7744\2140230891.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
# anouther heatmap of dataframe

corr = df.corr()
sns.set()
ax = sns.heatmap(corr, vmin=0, vmax=1)
plt.show()
# Out:
# C:\Users\m\AppData\Local\Temp\ipykernel_7744\1492213210.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
